# %%
# !pip install -U pandas-profiling
# Out:
# Requirement already up-to-date: pandas-profiling in /usr/local/lib/python3.7/dist-packages (3.0.0)
# ...

# %% [markdown]
# now we should import the library's into code

# %%
import pandas as pd
from pandas_profiling import ProfileReport

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
DatasetBaseFolder = '/content/gdrive/MyDrive/ColabNotebooks/PandasTl/Datasets/'

# %% [markdown]
# reading the dataset which is downloaded from kaggle. Basically, the dataset is about different aspects(economy,population,area,etc...) of countries in UNITED STATES OF AMERICA

# %%
county = pd.read_csv(DatasetBaseFolder+"county_facts.csv")

# %%
county.head()
# Out:
#    fips       area_name state_abbreviation  ...  BPS030214   LND110210  POP060210
# 0     0   United States                NaN  ...    1046363  3531905.43       87.4
# 1  1000         Alabama                NaN  ...      13369    50645.33       94.4
# 2  1001  Autauga County                 AL  ...        131      594.44       91.8
# 3  1003  Baldwin County                 AL  ...       1384     1589.78      114.6
# 4  1005  Barbour County                 AL  ...          8      884.88       31.0
#
# [5 rows x 54 columns]

# %% [markdown]
# histogram of the dataset

# %%
#matplotlib inline
county.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f1863214710>,
# ...
#       dtype=object)

# %% [markdown]
# making a documental report of the dataset like collection of statistical reports

# %%
county_profile = county.profile_report(title = "USA COUNTRIES REPORT")

# %% [markdown]
# Loading the report into a html file

# %%
county_profile.to_file(output_file = "county.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
